# %%
from Bio import SeqIO
from pandas import Series, DataFrame
import pandas as pd
import pylab
from Bio.SeqUtils import GC

# %%
# !pwd
# Out:
# /Users/migueldelrio/Desktop/analisis/jupyter

# %%
# !ls ../../data/
# Out:
# Hrufescens_mtDNASequences from NCBI.fasta

# %%
# fasta file to calculate the CpG content per contig
handle = "../../data/Hrufescens_mtDNASequences from NCBI.fasta"

# %%
record_id = []
record_cpg = []
for record in SeqIO.parse(handle, "fasta") :
    g= record.seq.count("G")
    c= record.seq.count("C")
    cg= record.seq.count("CG")
    lar= len(record.seq)
    try:
        g*c==0
    except:
        print (record.id)
        record_id.append(record.id)
        record_cpg.append(0.0000)
    else:
        print (record.id, round(cg/(g*c)*(lar**2/(lar-1) ) ,8))
        record_id.append(record.id)
        record_cpg.append(round(cg/(g*c),8))
# Out:
# JF281275 0.61457671
# JF281274 0.63821427
# JF281273 0.63821427
# JF281272 0.63821427
# JF281271 0.63821427
# JF281270 0.63013561
# JF281269 0.63821427
# JF281268 0.62225891
# JF281267 0.62225891
# JF281266 0.61457671
# HM595789 0.61703232
# HM595768 0.55308307
# EU636207 0.70329902
# EU636201 0.68212544
# AY679086 0.59599912
# AY679085 0.60233953
# AY679084 0.59599912
# AY679083 0.6088163
# AY679082 0.60233953
# DQ297549 0.57857719
# DQ297548 0.56946574
# DQ297547 0.57398531
# DQ297546 0.58749085
# DQ297545 0.58530483
# DQ297544 0.57398531
# DQ297543 0.58065956
# DQ297542 0.52800226
# DQ297541 0.55859614
# DQ297540 0.58286493
# DQ297539 0.56946574
# DQ297538 0.61555496
# DQ297537 0.58065956
# DQ297536 0.6132708
# DQ297535 0.57608744
# DQ297534 0.56946574
# DQ297533 0.56946574
# DQ297532 0.58286493
# DQ297531 0.57158675
# DQ297530 0.57608744
# DQ297529 0.58286493
# DQ297528 0.58286493
# DQ297527 0.57608744
# DQ297526 0.58286493
# DQ297525 0.57608744
# DQ297524 0.58749085
# DQ297523 0.57608744
# DQ297522 0.62040185
# DQ297521 0.58065956
# DQ297520 0.58065956
# DQ297519 0.58530483
# DQ297518 0.58749085
# DQ297517 0.58286493
# DQ297516 0.58749085
# DQ297515 0.58519596
# DQ297514 0.58286493
# DQ297513 0.59690987
# DQ297512 0.58286493
# DQ297511 0.59690987
# DQ297510 0.59448479
# DQ297509 0.58286493
# DQ297508 0.58286493
# DQ297507 0.5898038
# AY817732 0.87273787
# AY817717 0.56556056
# AY650164 0.71851431
# AF060843 0.60046323
# AF060842 0.61337641
# AF060841 0.6009109
# AF060840 0.6009109
# AF060839 0.61773749
# AF060838 0.61383372
# AF060837 0.61383372
# AF060836 0.62242374
# AF060835 0.6009109
# AY428963 0.62649165

# %%
records = DataFrame({'id':record_id, 'CpG':record_cpg})
records
# Out:
#          CpG        id
# 0   0.001305  JF281275
# 1   0.001355  JF281274
# 2   0.001355  JF281273
# 3   0.001355  JF281272
# 4   0.001355  JF281271
# 5   0.001338  JF281270
# 6   0.001355  JF281269
# 7   0.001321  JF281268
# 8   0.001321  JF281267
# 9   0.001305  JF281266
# 10  0.001126  HM595789
# 11  0.001311  HM595768
# 12  0.001274  EU636207
# 13  0.001220  EU636201
# 14  0.001112  AY679086
# 15  0.001124  AY679085
# 16  0.001112  AY679084
# 17  0.001136  AY679083
# 18  0.001124  AY679082
# 19  0.001195  DQ297549
# 20  0.001177  DQ297548
# 21  0.001186  DQ297547
# 22  0.001214  DQ297546
# 23  0.001209  DQ297545
# 24  0.001186  DQ297544
# 25  0.001200  DQ297543
# 26  0.001091  DQ297542
# 27  0.001154  DQ297541
# 28  0.001204  DQ297540
# 29  0.001177  DQ297539
# ..       ...       ...
# 45  0.001190  DQ297523
# 46  0.001282  DQ297522
# 47  0.001200  DQ297521
# 48  0.001200  DQ297520
# 49  0.001209  DQ297519
# 50  0.001214  DQ297518
# 51  0.001204  DQ297517
# 52  0.001214  DQ297516
# 53  0.001209  DQ297515
# 54  0.001204  DQ297514
# 55  0.001233  DQ297513
# 56  0.001204  DQ297512
# 57  0.001233  DQ297511
# 58  0.001228  DQ297510
# 59  0.001204  DQ297509
# 60  0.001204  DQ297508
# 61  0.001219  DQ297507
# 62  0.003030  AY817732
# 63  0.001500  AY817717
# 64  0.001431  AY650164
# 65  0.001153  AF060843
# 66  0.001177  AF060842
# 67  0.001136  AF060841
# 68  0.001136  AF060840
# 69  0.001253  AF060839
# 70  0.001160  AF060838
# 71  0.001160  AF060837
# 72  0.001190  AF060836
# 73  0.001136  AF060835
# 74  0.001488  AY428963
#
# [75 rows x 2 columns]

# %%
records.describe()
# Out:
#              CpG
# count  75.000000
# mean    0.001248
# std     0.000224
# min     0.001091
# 25%     0.001179
# 50%     0.001204
# 75%     0.001260
# max     0.003030
